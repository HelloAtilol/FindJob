# %%
import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.0.0
# 2.2.4-tf

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
#设置优化器、损失函数、评价指标
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=[tf.keras.metrics.categorical_accuracy])

# 简单输入numpy数据
import numpy as np

train_x = np.random.random((1000, 72))
train_y = np.random.random((1000, 10))

val_x = np.random.random((200, 72))
val_y = np.random.random((200, 10))

# 开始训练
model.fit(train_x, train_y, epochs=10, batch_size=100, validation_data=(val_x, val_y))
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/10
# 1000/1000 [==============================] - 1s 919us/sample - loss: 11.7720 - categorical_accuracy: 0.0950 - val_loss: 11.5846 - val_categorical_accuracy: 0.1050
# Epoch 2/10
# 1000/1000 [==============================] - 0s 35us/sample - loss: 11.7577 - categorical_accuracy: 0.1050 - val_loss: 11.7093 - val_categorical_accuracy: 0.1100
# Epoch 3/10
# 1000/1000 [==============================] - 0s 36us/sample - loss: 12.0134 - categorical_accuracy: 0.0980 - val_loss: 12.1663 - val_categorical_accuracy: 0.0950
# Epoch 4/10
# 1000/1000 [==============================] - 0s 37us/sample - loss: 12.7153 - categorical_accuracy: 0.0950 - val_loss: 13.2631 - val_categorical_accuracy: 0.1000
# Epoch 5/10
# 1000/1000 [==============================] - 0s 32us/sample - loss: 14.2527 - categorical_accuracy: 0.0950 - val_loss: 15.4003 - val_categorical_accuracy: 0.1000
# Epoch 6/10
# 1000/1000 [==============================] - 0s 35us/sample - loss: 16.9169 - categorical_accuracy: 0.0960 - val_loss: 18.6132 - val_categorical_accuracy: 0.1000
# Epoch 7/10
# 1000/1000 [==============================] - 0s 34us/sample - loss: 20.1298 - categorical_accuracy: 0.0960 - val_loss: 21.4192 - val_categorical_accuracy: 0.1000
# Epoch 8/10
# 1000/1000 [==============================] - 0s 35us/sample - loss: 22.6643 - categorical_accuracy: 0.0980 - val_loss: 24.2890 - val_categorical_accuracy: 0.0650
# Epoch 9/10
# 1000/1000 [==============================] - 0s 38us/sample - loss: 26.6248 - categorical_accuracy: 0.0970 - val_loss: 29.1884 - val_categorical_accuracy: 0.0550
# Epoch 10/10
# 1000/1000 [==============================] - 0s 33us/sample - loss: 31.9119 - categorical_accuracy: 0.0960 - val_loss: 34.6448 - val_categorical_accuracy: 0.0950

# %%
# tf.data输入数据
dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()
val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.batch(32)
val_dataset = val_dataset.repeat()

model.fit(dataset, epochs=10, steps_per_epoch=30, validation_data=val_dataset, validation_steps=3)
# Out:
# Train for 30 steps, validate for 3 steps
# Epoch 1/10
# 30/30 [==============================] - 0s 12ms/step - loss: 46.2848 - categorical_accuracy: 0.0958 - val_loss: 61.1075 - val_categorical_accuracy: 0.0417
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 79.0306 - categorical_accuracy: 0.1015 - val_loss: 101.9197 - val_categorical_accuracy: 0.0521
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 126.0679 - categorical_accuracy: 0.0983 - val_loss: 154.4466 - val_categorical_accuracy: 0.0417
# Epoch 4/10
# 30/30 [==============================] - 0s 2ms/step - loss: 185.7442 - categorical_accuracy: 0.1004 - val_loss: 222.1362 - val_categorical_accuracy: 0.0729
# Epoch 5/10
# 30/30 [==============================] - 0s 2ms/step - loss: 258.7653 - categorical_accuracy: 0.0908 - val_loss: 301.9385 - val_categorical_accuracy: 0.0625
# Epoch 6/10
# 30/30 [==============================] - 0s 2ms/step - loss: 343.5131 - categorical_accuracy: 0.0919 - val_loss: 392.9702 - val_categorical_accuracy: 0.0938
# Epoch 7/10
# 30/30 [==============================] - 0s 2ms/step - loss: 439.2485 - categorical_accuracy: 0.0876 - val_loss: 492.7325 - val_categorical_accuracy: 0.0521
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 542.3474 - categorical_accuracy: 0.0791 - val_loss: 596.9039 - val_categorical_accuracy: 0.0833
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 646.7170 - categorical_accuracy: 0.0994 - val_loss: 701.8019 - val_categorical_accuracy: 0.1042
# Epoch 10/10
# 30/30 [==============================] - 0s 2ms/step - loss: 751.5030 - categorical_accuracy: 0.0940 - val_loss: 800.6280 - val_categorical_accuracy: 0.0625

# %%
# 评估与预测
test_x = np.random.random((1000, 72))
test_y = np.random.random((1000, 10))
model.evaluate(test_x, test_y, batch_size=32)
test_data = tf.data.Dataset.from_tensor_slices((test_x, test_y))
test_data = test_data.batch(32).repeat()
model.evaluate(test_data, steps=30)
# predict
result = model.predict(test_x, batch_size=32)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 30/30 [==============================] - 0s 1ms/step - loss: 810.2983 - categorical_accuracy: 0.0990

# %%
# 查看结果
print(result)
# Out:
# [[0.00000000e+00 5.88249899e-02 4.78782535e-01 ... 2.64146643e-24
#   0.00000000e+00 7.36391097e-02]
#  [0.00000000e+00 8.19986761e-02 3.77126992e-01 ... 3.56301231e-25
#   0.00000000e+00 6.59843683e-02]
#  [0.00000000e+00 5.82512878e-02 5.44370174e-01 ... 8.30491499e-27
#   0.00000000e+00 7.45773241e-02]
#  ...
#  [0.00000000e+00 7.91277364e-02 5.77867568e-01 ... 6.63939296e-26
#   0.00000000e+00 4.19629104e-02]
#  [0.00000000e+00 5.38756512e-02 4.14960146e-01 ... 9.04303735e-26
#   0.00000000e+00 1.00407526e-01]
#  [0.00000000e+00 6.80136606e-02 5.52759707e-01 ... 4.42284388e-26
#   0.00000000e+00 7.04129040e-02]]

# %%
input_x = tf.keras.Input(shape=(72,))
hidden1 = layers.Dense(32, activation='relu')(input_x)
hidden2 = layers.Dense(16, activation='relu')(hidden1)
pred = layers.Dense(10, activation='softmax')(hidden2)

model = tf.keras.Model(inputs=input_x, outputs=pred)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss=tf.keras.losses.categorical_crossentropy,
             metrics=['accuracy'])
history = model.fit(train_x, train_y, batch_size=32, epochs=5)
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 489us/sample - loss: 13.1533 - accuracy: 0.0930
# Epoch 2/5
# 1000/1000 [==============================] - 0s 48us/sample - loss: 20.9976 - accuracy: 0.0990
# Epoch 3/5
# 1000/1000 [==============================] - 0s 47us/sample - loss: 34.9309 - accuracy: 0.1050
# Epoch 4/5
# 1000/1000 [==============================] - 0s 48us/sample - loss: 63.6624 - accuracy: 0.1000
# Epoch 5/5
# 1000/1000 [==============================] - 0s 47us/sample - loss: 112.2067 - accuracy: 0.1050

# %%
# 模型保存
model.save('model_save.h5')

# %%
# 模型序列化
del model
from tensorflow import keras
model = keras.models.load_model('model_save.h5')

# %%
# 使用一个输入层和一个输出层，使用共享网络创建多个模型
encode_input = keras.Input(shape=(28,28,1), name='img')
h1 = layers.Conv2D(16, 3, activation='relu')(encode_input)
h1 = layers.Conv2D(32, 3, activation='relu')(h1)
h1 = layers.MaxPool2D(3)(h1)
h1 = layers.Conv2D(32, 3, activation='relu')(h1)
h1 = layers.Conv2D(16, 3, activation='relu')(h1)
encode_output = layers.GlobalMaxPool2D()(h1)

encode_model = keras.Model(inputs=encode_input, outputs=encode_output, name='encoder')
encode_model.summary()

h2 = layers.Reshape((4, 4, 1))(encode_output)
h2 = layers.Conv2DTranspose(16, 3, activation='relu')(h2)
h2 = layers.Conv2DTranspose(32, 3, activation='relu')(h2)
h2 = layers.UpSampling2D(3)(h2)
h2 = layers.Conv2DTranspose(16, 3, activation='relu')(h2)
decode_output = layers.Conv2DTranspose(1, 3, activation='relu')(h2)

autoencoder = keras.Model(inputs=encode_input, outputs=decode_output, name='autoencoder')
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 32)          9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 16)          4624
# _________________________________________________________________
# global_max_pooling2d (Global (None, 16)                0
# =================================================================
# Total params: 18,672
# Trainable params: 18,672
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 32)          9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 16)          4624
# _________________________________________________________________
# global_max_pooling2d (Global (None, 16)                0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 1)           0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 6, 6, 16)          160
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 32)          4640
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 26, 26, 16)        4624
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         145
# =================================================================
# Total params: 28,241
# Trainable params: 28,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 将一个模型当作一层

encode_input = keras.Input(shape=(28,28,1), name='src_img')
h1 = layers.Conv2D(16, 3, activation='relu')(encode_input)
h1 = layers.Conv2D(32, 3, activation='relu')(h1)
h1 = layers.MaxPool2D(3)(h1)
h1 = layers.Conv2D(32, 3, activation='relu')(h1)
h1 = layers.Conv2D(16, 3, activation='relu')(h1)
encode_output = layers.GlobalMaxPool2D()(h1)

encode_model = keras.Model(inputs=encode_input, outputs=encode_output, name='encoder')
encode_model.summary()

decode_input = keras.Input(shape=(16,), name='encoded_img')
h2 = layers.Reshape((4, 4, 1))(decode_input)
h2 = layers.Conv2DTranspose(16, 3, activation='relu')(h2)
h2 = layers.Conv2DTranspose(32, 3, activation='relu')(h2)
h2 = layers.UpSampling2D(3)(h2)
h2 = layers.Conv2DTranspose(16, 3, activation='relu')(h2)
decode_output = layers.Conv2DTranspose(1, 3, activation='relu')(h2)
decode_model = keras.Model(inputs=decode_input, outputs=decode_output, name='decoder')
decode_model.summary()

autoencoder_input = keras.Input(shape=(28,28,1), name='img')
h3 = encode_model(autoencoder_input)
autoencoder_output = decode_model(h3)
autoencoder = keras.Model(inputs=autoencoder_input, outputs=autoencoder_output,
                          name='autoencoder')
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# src_img (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 32)          9248
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 16)          4624
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 16)                0
# =================================================================
# Total params: 18,672
# Trainable params: 18,672
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_img (InputLayer)     [(None, 16)]              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 1)           0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 6, 6, 16)          160
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 8, 8, 32)          4640
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 26, 26, 16)        4624
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 28, 28, 1)         145
# =================================================================
# Total params: 9,569
# Trainable params: 9,569
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 28, 28, 1)]       0
# _________________________________________________________________
# encoder (Model)              (None, 16)                18672
# _________________________________________________________________
# decoder (Model)              (None, 28, 28, 1)         9569
# =================================================================
# Total params: 28,241
# Trainable params: 28,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 共享网络层
share_embedding = layers.Embedding(1000, 64)

input1 = keras.Input(shape=(None,), dtype='int32')
input2 = keras.Input(shape=(None,), dtype='int32')

feat1 = share_embedding(input1)
feat2 = share_embedding(input2)

# %%
x = [[3.]]
m = tf.matmul(x, x)
print(m.numpy())
# Out:
# [[9.]]
